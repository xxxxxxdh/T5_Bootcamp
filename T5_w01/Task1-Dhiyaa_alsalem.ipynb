# %% [markdown]
# #Dataset Description

# %% [markdown]
# \
#
# ## The dataset contains information about road traffic accidents with the following columns:
#
# `Time`: Time of the accident
#
# `Day_of_week`: Day of the week when the accident occurred
#
# `Age_band_of_driver`: Age group of the driver
#
# `Sex_of_driver`: Gender of the driver
#
# `Educational_level`: Educational level of the driver
#
# `Vehicle_driver_relation`: Relationship of the driver to the vehicle
#
# `Driving_experience`: Driving experience of the driver
#
# `Type_of_vehicle`: Type of vehicle involved in the accident
#
# `Owner_of_vehicle`: Owner of the vehicle
#
# `Service_year_of_vehicle`: Service years of the vehicle
#
# `Area_accident_occured`: Area where the accident occurred
#
# `Lanes_or_Medians`: Lanes or medians at the accident site
#
# `Road_allignment`: Road alignment at the accident site
#
# `Types_of_Junction`: Type of junction at the accident site
#
# `Road_surface_type`: Type of road surface at the accident site
#
# `Road_surface_conditions`: Road surface conditions at the accident site
#
# `Light_conditions`: Light conditions at the time of the accident
#
# `Weather_conditions`: Weather conditions at the time of the accident
#
# `Type_of_collision`: Type of collision
#
# `Number_of_vehicles_involved`: Number of vehicles involved in the accident
#
# `Number_of_casualties`: Number of casualties in the accident
#
# `Vehicle_movement`: Movement of the vehicle during the accident
#
# `Casualty_class`: Class of casualty (driver, passenger, pedestrian)
#
# `Sex_of_casualty`: Gender of the casualty
#
# `Age_band_of_casualty`: Age group of the casualty
#
# `Casualty_severity`: Severity of the casualty
#
# `Work_of_casuality`: Occupation of the casualty
#
# `Fitness_of_casuality`: Fitness of the casualty
#
# `Pedestrian_movement`: Movement of the pedestrian
#
# `Cause_of_accident`: Cause of the accident
#
# `Accident_severity`: Severity of the accident

# %% [markdown]
# # Tasks

# %% [markdown]
# ##1. Data Cleaning

# %% [markdown]
# ### Read the dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/Task (1) Dataset.csv") #reading data
df
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 0       Above high school                Employee              1-2yr
# 1      Junior high school                Employee         Above 10yr
# ...

# %%
df.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# ...

# %%
df.tail()
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 12311                 NaN                Employee              2-5yr
# 12312   Elementary school                Employee             5-10yr
# 12313  Junior high school                Employee             5-10yr
# 12314  Junior high school                Employee         Above 10yr
# 12315  Junior high school                Employee             5-10yr
#
#        Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 12311   Lorry (11?40Q)            Owner                     NaN  ...
# ...

# %%
df.sample()
# Out:
#         Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 14  17:45:00    Thursday              31-50          Male  Junior high school
#
#    Vehicle_driver_relation Driving_experience Type_of_vehicle  \
# 14                Employee         Above 10yr      Automobile
#
#    Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# 14            Owner                   1-2yr  ...   Going straight
#
#      Casualty_class Sex_of_casualty Age_band_of_casualty Casualty_severity  \
# 14  Driver or rider          Female                18-30                 3
#
#    Work_of_casuality Fitness_of_casuality Pedestrian_movement  \
# 14            Driver               Normal    Not a Pedestrian
#
#    Cause_of_accident Accident_severity
# 14     No distancing    Serious Injury
#
# [1 rows x 32 columns]

# %%
df.shape
# Out:
# (12316, 32)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  object
#  1   Day_of_week                  12316 non-null  object
#  2   Age_band_of_driver           12316 non-null  object
#  3   Sex_of_driver                12316 non-null  object
#  4   Educational_level            11575 non-null  object
#  5   Vehicle_driver_relation      11737 non-null  object
#  6   Driving_experience           11487 non-null  object
#  7   Type_of_vehicle              11366 non-null  object
#  8   Owner_of_vehicle             11834 non-null  object
#  9   Service_year_of_vehicle      8388 non-null   object
#  10  Defect_of_vehicle            7889 non-null   object
#  11  Area_accident_occured        12077 non-null  object
#  12  Lanes_or_Medians             11931 non-null  object
# ...

# %% [markdown]
# ### Handle Missing Values

# %%
df.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %%
columns_to_fill_with_mode = [
    'Educational_level', 'Vehicle_driver_relation', 'Driving_experience',
    'Type_of_vehicle', 'Owner_of_vehicle', 'Service_year_of_vehicle',
    'Defect_of_vehicle', 'Area_accident_occured', 'Lanes_or_Medians',
    'Road_allignment', 'Types_of_Junction', 'Road_surface_type',
    'Type_of_collision', 'Vehicle_movement', 'Work_of_casuality', 'Fitness_of_casuality'
]#easier way

for column in columns_to_fill_with_mode:
    mode_value = df[column].mode()[0]
    df[column].fillna(mode_value, inplace=True)

#some columns does not have null values but have instead (na) or (unknown)
value_counts1 = df['Casualty_severity'].value_counts()
next_most_frequent_value1 = value_counts1.drop('na').idxmax()
df['Casualty_severity'].replace('na', next_most_frequent_value1, inplace=True)

value_counts = df['Age_band_of_casualty'].value_counts()
next_most_frequent_value = value_counts.drop('na').idxmax()
df['Age_band_of_casualty'].replace('na', next_most_frequent_value, inplace=True)

value_counts = df['Casualty_class'].value_counts()
next_most_frequent_value = value_counts.drop('na').idxmax()
df['Casualty_class'].replace('na', next_most_frequent_value, inplace=True)

value_counts = df['Sex_of_casualty'].value_counts()
next_most_frequent_value = value_counts.drop('na').idxmax()
df['Sex_of_casualty'].replace('na', next_most_frequent_value, inplace=True)

value_counts = df['Sex_of_driver'].value_counts()
next_most_frequent_value = value_counts.drop('Unknown').idxmax()
df['Sex_of_driver'].replace('Unknown', next_most_frequent_value, inplace=True)

value_counts = df['Service_year_of_vehicle'].value_counts()
next_most_frequent_value = value_counts.drop('Unknown').idxmax()
df['Service_year_of_vehicle'].replace('Unknown', next_most_frequent_value, inplace=True)

value_counts = df['Age_band_of_driver'].value_counts()
next_most_frequent_value = value_counts.drop('Unknown').idxmax()
df['Age_band_of_driver'].replace('Unknown', next_most_frequent_value, inplace=True)

# %%
df.isnull().sum()
# Out:
# Time                           0
# Day_of_week                    0
# Age_band_of_driver             0
# Sex_of_driver                  0
# Educational_level              0
# Vehicle_driver_relation        0
# Driving_experience             0
# Type_of_vehicle                0
# Owner_of_vehicle               0
# Service_year_of_vehicle        0
# Defect_of_vehicle              0
# Area_accident_occured          0
# Lanes_or_Medians               0
# Road_allignment                0
# Types_of_Junction              0
# Road_surface_type              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Type_of_collision              0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Vehicle_movement               0
# Casualty_class                 0
# Sex_of_casualty                0
# Age_band_of_casualty           0
# Casualty_severity              0
# Work_of_casuality              0
# ...

# %%
df.duplicated().sum() #checking for duplicate values
# Out:
# 0

# %% [markdown]
# ### Correct any inconsistent data entries.

# %%
#1
df['Day_of_week'] = df['Day_of_week'].str.capitalize()

#2
df['Educational_level'] = df['Educational_level'].replace({
    'Writing & reading': 'Literate' #its the same thing
})

#3
df['Type_of_vehicle'] = df['Type_of_vehicle'].replace({
    'Lorry (41?100Q)': 'Lorry (41-100Q)',
    'Lorry (11?40Q)': 'Lorry (11-40Q)',
    'Public (> 45 seats)': 'Bus (> 45 seats)',
    'Public (13?45 seats)': 'Bus (13-45 seats)',
    'Public (12 seats)': 'Bus (12 seats)',
    'Ridden horse': 'Horse'
}) #عشان تصير مرتبة

#4
df['Fitness_of_casuality'] = df['Fitness_of_casuality'].replace({
    'NormalNormal': 'Normal'
})# because in the dataset we have normal and normalnormal so i need them all to be normal

# %%
df #to check after everything
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday              18-30          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 0       Above high school                Employee              1-2yr
# 1      Junior high school                Employee         Above 10yr
# ...

# %% [markdown]
# ### Ensure data types are appropriate for each column.
#
# ---

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  object
#  1   Day_of_week                  12316 non-null  object
#  2   Age_band_of_driver           12316 non-null  object
#  3   Sex_of_driver                12316 non-null  object
#  4   Educational_level            12316 non-null  object
#  5   Vehicle_driver_relation      12316 non-null  object
#  6   Driving_experience           12316 non-null  object
#  7   Type_of_vehicle              12316 non-null  object
#  8   Owner_of_vehicle             12316 non-null  object
#  9   Service_year_of_vehicle      12316 non-null  object
#  10  Defect_of_vehicle            12316 non-null  object
#  11  Area_accident_occured        12316 non-null  object
#  12  Lanes_or_Medians             12316 non-null  object
# ...

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %%
df['Sex_of_driver'].value_counts()
# Out:
# Sex_of_driver
# Male      11615
# Female      701
# Name: count, dtype: int64

# %%
df['Type_of_vehicle'].value_counts()
# Out:
# Type_of_vehicle
# Automobile           4155
# Lorry (41-100Q)      2186
# Other                1208
# Pick up upto 10Q      811
# Bus (12 seats)        711
# Stationwagen          687
# Lorry (11-40Q)        541
# Bus (13-45 seats)     532
# Bus (> 45 seats)      404
# Long lorry            383
# Taxi                  265
# Motorcycle            177
# Special vehicle        84
# Horse                  76
# Turbo                  46
# Bajaj                  29
# Bicycle                21
# Name: count, dtype: int64

# %%
df['Educational_level'].value_counts()
# Out:
# Educational_level
# Junior high school    8360
# Elementary school     2163
# High school           1110
# Above high school      362
# Literate               176
# Unknown                100
# Illiterate              45
# Name: count, dtype: int64

# %%
df['Age_band_of_casualty'].value_counts()
# Out:
# Age_band_of_casualty
# 18-30       7588
# 31-50       2455
# Under 18    1035
# Over 51      994
# 5            244
# Name: count, dtype: int64

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
df.describe()
# Out:
#        Number_of_vehicles_involved  Number_of_casualties
# count                 12316.000000          12316.000000
# mean                      2.040679              1.548149
# std                       0.688790              1.007179
# min                       1.000000              1.000000
# 25%                       2.000000              1.000000
# 50%                       2.000000              1.000000
# 75%                       2.000000              2.000000
# max                       7.000000              8.000000

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Age_band_of_driver, Type_of_vehicle).

# %%
df.hist(figsize=(15,12))
# Out:
# array([[<Axes: title={'center': 'Number_of_vehicles_involved'}>,
#         <Axes: title={'center': 'Number_of_casualties'}>]], dtype=object)

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df['Age_band_of_driver'], bins=20)
plt.xlabel('Age Band of Drivers')
plt.title('Distribution of Age Band of Drivers')
plt.xticks(rotation=45)
plt.show()

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
#in the boxplot above it shows that we have ouliers and we need to remove them

def remove_outliers(df, column):
  Q1 = df[column].quantile(0.25)
  Q3 = df[column].quantile(0.75)
  IQR = Q3 - Q1
  lower_bound = Q1 - 1.5 * IQR
  upper_bound = Q3 + 1.5 * IQR
  df = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
  return df

df = remove_outliers(df, 'Number_of_vehicles_involved')
df = remove_outliers(df, 'Number_of_casualties')

from sklearn.preprocessing import StandardScaler #so no feature dominate the other
scaler = StandardScaler()
df[['Number_of_vehicles_involved', 'Number_of_casualties']] = scaler.fit_transform(df[['Number_of_vehicles_involved', 'Number_of_casualties']])
df.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# ### Explore relationships between variables (e.g., Age_band_of_driver vs. Accident_severity).

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(data=df, x='Age_band_of_driver', y='Number_of_casualties', hue='Accident_severity', palette='coolwarm', alpha=0.6)
plt.title('Age Band of Driver vs. Number of Casualties')
plt.xlabel('Age Band of Driver')
plt.ylabel('Number of Casualties')
plt.xticks(rotation=45)
plt.legend(title='Accident Severity')
plt.show()

# %% [markdown]
# ## 3. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %%
plt.figure(figsize=(8, 8))
severity_counts = df['Accident_severity'].value_counts()
plt.pie(severity_counts, labels=severity_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Accident Severity')
plt.show()

# %%
plt.figure(figsize=(8, 8))
gender_counts = df['Sex_of_driver'].value_counts()
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Gender of Drivers')
plt.show()

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %%
plt.figure(figsize=(12, 6))
sns.violinplot(data=df, x='Age_band_of_driver', y='Number_of_casualties', palette='muted')
plt.title('Distribution of Number of Casualties by Age Band of Driver')
plt.xlabel('Age Band of Driver')
plt.ylabel('Number of Casualties')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-536-7d37d172b22f>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x='Age_band_of_driver', y='Number_of_casualties', palette='muted')

# %% [markdown]
# ## 4. Insights and Conclusions

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>
